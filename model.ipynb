# %%
#ライブラリのインポート
import pandas as pd

# %%
#マウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#カレントファイルに移動
# %cd /content/drive/MyDrive/Colab Notebooks/Nishika/Boke_ai
# Out:
# /content/drive/MyDrive/Colab Notebooks/Nishika/Boke_ai

# %%
ls
# Out:
#  ボケのデザインパターン2022.pdf   git.ipynb               test.csv
#  data_explanation.xlsx            model.ipynb            'train '/
#  debug.ipynb                      sample_submission.csv   train.csv
#  Docs.gdoc                        test/                   ボケ方AIとの違い.pdf

# %% [markdown]
# ##データの準備

# %%
train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Nishika/Boke_ai/train.csv")
test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Nishika/Boke_ai/test.csv")

# %%
train["is_train"] = 1
test["is_train"] = 0

# %%
data = pd.concat([train, test])

# %%
data
# Out:
#              id odai_photo_file_name  \
# 0     ge5kssftl       9fkys1gb2r.jpg
# 1     r7sm6tvkj       c6ag0m1lak.jpg
# 2     yp5aze0bh       whtn6gb9ww.jpg
# 3     ujaixzo56       6yk5cwmrsy.jpg
# 4     7vkeveptl       0i9gsa2jsm.jpg
# ...         ...                  ...
# 5995  vx1lpzark       0bgwr5po4l.jpg
# 5996  y9sugbhm8       3wgkjwrq11.jpg
# 5997  dsd1yixzk       rny98dohwa.jpg
# 5998  vmyopn0mu       rlrze2yhes.jpg
# 5999  sveiueszw       khnyiksntu.jpg
#
#                                                    text  is_laugh  is_train
# 0                    君しょっちゅうソレ自慢するけど、ツムジ２個ってそんなに嬉しいのかい？       0.0         1
# 1                                   これでバレない？授業中寝てもバレない？       0.0         1
# 2         「あなたも感じる？」\n『ああ…、感じてる…』\n「後ろに幽霊いるよね…」\n『女のな…』       0.0         1
# 3                        大塚愛聞いてたらお腹減った…さく、らんぼと牛タン食べたい…        0.0         1
# 4                                           熊だと思ったら嫁だった       0.0         1
# ...
